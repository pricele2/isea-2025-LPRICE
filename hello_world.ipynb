# %% [markdown]
# <a href="https://colab.research.google.com/github/pricele2/isea-2025-LPRICE/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Test
# 1. Please run the 'Hello world' block
# 2. Please create a code cell below, type your own `print("i can run this")` statement and run it.
#
# We will use colab in class.

# %%
print("hello world")
# Out:
# hello world
